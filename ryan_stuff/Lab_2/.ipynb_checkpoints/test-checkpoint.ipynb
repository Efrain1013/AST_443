# %%
from astropy.io import fits
import matplotlib.pyplot as plt

image = fits.open('../../Lab_2/images/lab2_science_red_20s.00000060.FIT')

data = image[0].data

plt.imshow(data,vmin=0,vmax=3500,cmap='gray')
plt.colorbar()
